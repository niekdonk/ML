# %%
# Out:
# 52213 25717

# %%
# Out:
# Epoch 1/100
# 52211/52211 [==============================] - 56s 1ms/step - loss: 0.0359
# Epoch 2/100
# 52211/52211 [==============================] - 56s 1ms/step - loss: 0.0345
# Epoch 3/100
#  2203/52211 [>.............................] - ETA: 55s - loss: 0.0348
